# %%
import tdt
#import matplotlib.pyplot as plt
import trompy as tp
import numpy as np
import pickle
import pandas as pd
#%matplotlib inline

# %%
DATAFOLDER = "D:\\Data\\photometry\\HistaLight_cohort3\\"
METAFILE = "..\\data\\HL_cohort3_metafile.csv"

metafile_data = pd.read_csv(METAFILE)

# %%
def get_streams(row, data):

    blue = getattr(data.streams, row.signal_blue).data
    UV = getattr(data.streams,row.signal_uv).data

    fs = getattr(data.streams,row.signal_uv).fs

    corrected = tp.processdata(blue, UV)
    
    return corrected, fs

# %%
def get_ttls(row, data):
 
    if row.R_number_licks> 0:
        return getattr(data.epocs, row.ttl_lick_right).onset
    else:
        return []

# %%
def get_data_from_metafile(row):
    print("analyzing", row.mouse, row.session)
    d= {}

    d["mouse_ID"] = row.mouse
    d["region"] = row.region
    d["virus"] = row.virus
    d["diet"] = row.diet
    d["total_licks"] = row.total_licks
    
    d["solution"]=row.R_nutrient
    
    data = tdt.read_block(DATAFOLDER+row.tdt_file)
    corrected, fs = get_streams(row, data)

    d["corrected"] = corrected
    d["fs"] = fs

    d["licks"] = get_ttls(row, data)
    

    return d

# %%
all_data ={}

for index, row in metafile_data.iterrows():
    if row.phase == "unrestricted_continuous_access":

        key=row.mouse+"_"+str(row.session)
        
        all_data[key]=get_data_from_metafile(row)
# Out:
# analyzing HL301 1
# read from t=0s to t=1973.44s
# analyzing HL302 1
# read from t=0s to t=1973.44s
# analyzing HL303 1
# read from t=0s to t=1973.44s
# analyzing HL304 1
# read from t=0s to t=1973.44s
# analyzing HL305 1
# read from t=0s to t=1986.94s
# analyzing HL306 1
# read from t=0s to t=1986.94s
# analyzing HL307 1
# read from t=0s to t=1986.94s
# analyzing HL308 1
# read from t=0s to t=1986.94s
# analyzing HL309 1
# read from t=0s to t=1959.76s
# analyzing HL310 1
# read from t=0s to t=1959.76s
# analyzing HL311 1
# read from t=0s to t=1959.76s
# analyzing HL312 1
# read from t=0s to t=1959.76s
# analyzing HL313 1
# read from t=0s to t=1966.31s
# analyzing HL314 1
# read from t=0s to t=1966.31s
# analyzing HL315 1
# read from t=0s to t=1966.31s
# analyzing HL316 1
# read from t=0s to t=1966.31s
# analyzing HL317 1
# read from t=0s to t=1922.1s
# analyzing HL318 1
# read from t=0s to t=1922.1s
# analyzing HL301 2
# read from t=0s to t=2000.2s
# analyzing HL302 2
# read from t=0s to t=2000.2s
# analyzing HL303 2
# read from t=0s to t=2000.2s
# analyzing HL304 2
# read from t=0s to t=2000.2s
# analyzing HL305 2
# read from t=0s to t=1974.02s
# analyzing HL306 2
# read from t=0s to t=1974.02s
# analyzing HL307 2
# read from t=0s to t=1974.02s
# analyzing HL308 2
# read from t=0s to t=1974.02s
# analyzing HL309 2
# read from t=0s to t=2207.9s
# analyzing HL310 2
# read from t=0s to t=2207.9s
# analyzing HL311 2
# read from t=0s to t=2207.9s
# analyzing HL312 2
# read from t=0s to t=2207.9s
# analyzing HL313 2
# read from t=0s to t=2290.36s
# analyzing HL314 2
# read from t=0s to t=2290.36s
# analyzing HL315 2
# read from t=0s to t=2290.36s
# analyzing HL316 2
# read from t=0s to t=2290.36s
# analyzing HL317 2
# read from t=0s to t=1921.01s
# analyzing HL318 2
# read from t=0s to t=1921.01s
# analyzing HL301 3
# read from t=0s to t=1950.7s
# analyzing HL302 3
# read from t=0s to t=1950.7s
# analyzing HL303 3
# read from t=0s to t=1950.7s
# analyzing HL304 3
# read from t=0s to t=1950.7s
# analyzing HL305 3
# read from t=0s to t=1906.08s
# analyzing HL306 3
# read from t=0s to t=1906.08s
# analyzing HL307 3
# read from t=0s to t=1906.08s
# analyzing HL308 3
# read from t=0s to t=1906.08s
# analyzing HL309 3
# read from t=0s to t=2062.94s
# analyzing HL310 3
# read from t=0s to t=2062.94s
# analyzing HL311 3
# read from t=0s to t=2062.94s
# analyzing HL312 3
# read from t=0s to t=2062.94s
# analyzing HL313 3
# read from t=0s to t=2056.82s
# analyzing HL314 3
# read from t=0s to t=2056.82s
# analyzing HL315 3
# read from t=0s to t=2056.82s
# analyzing HL316 3
# read from t=0s to t=2056.82s
# analyzing HL317 3
# read from t=0s to t=2018.48s
# analyzing HL318 3
# read from t=0s to t=2018.48s

# %%
#with open("C://Data//hislight_pickles//HL3_adlib_light.pickle", 'wb') as handle:
#    pickle.dump(all_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
all_data ={}

for index, row in metafile_data.iterrows():
    if row.phase == "food_restricted_continuous_access":

        key=row.mouse+"_"+str(row.session)
        
        all_data[key]=get_data_from_metafile(row)
# Out:
# analyzing HL301 4
# read from t=0s to t=1926.54s
# analyzing HL302 4
# read from t=0s to t=1926.54s
# analyzing HL303 4
# read from t=0s to t=1926.54s
# analyzing HL304 4
# read from t=0s to t=1926.54s
# analyzing HL305 4
# read from t=0s to t=2106.31s
# analyzing HL306 4
# read from t=0s to t=2106.31s
# analyzing HL307 4
# read from t=0s to t=2106.31s
# analyzing HL308 4
# read from t=0s to t=2106.31s
# analyzing HL309 4
# read from t=0s to t=2136.93s
# analyzing HL310 4
# read from t=0s to t=2136.93s
# analyzing HL311 4
# read from t=0s to t=2136.93s
# analyzing HL312 4
# read from t=0s to t=2136.93s
# analyzing HL313 4
# read from t=0s to t=2187.68s
# analyzing HL314 4
# read from t=0s to t=2187.68s
# analyzing HL315 4
# read from t=0s to t=2187.68s
# analyzing HL316 4
# read from t=0s to t=2187.68s
# analyzing HL317 4
# read from t=0s to t=2063.28s
# analyzing HL318 4
# read from t=0s to t=2063.28s
# analyzing HL301 5
# read from t=0s to t=1961.19s
# analyzing HL302 5
# read from t=0s to t=1961.19s
# analyzing HL303 5
# read from t=0s to t=1961.19s
# analyzing HL304 5
# read from t=0s to t=1961.19s
# analyzing HL305 5
# read from t=0s to t=1953.3s
# analyzing HL306 5
# read from t=0s to t=1953.3s
# analyzing HL307 5
# read from t=0s to t=1953.3s
# analyzing HL308 5
# read from t=0s to t=1953.3s
# analyzing HL309 5
# read from t=0s to t=1976.12s
# analyzing HL310 5
# read from t=0s to t=1976.12s
# analyzing HL311 5
# read from t=0s to t=1976.12s
# analyzing HL312 5
# read from t=0s to t=1976.12s
# analyzing HL313 5
# read from t=0s to t=2385.82s
# analyzing HL314 5
# read from t=0s to t=2385.82s
# analyzing HL315 5
# read from t=0s to t=2385.82s
# analyzing HL316 5
# read from t=0s to t=2385.82s
# analyzing HL317 5
# read from t=0s to t=1990.55s
# analyzing HL318 5
# read from t=0s to t=1990.55s
# analyzing HL301 6
# read from t=0s to t=2182.82s
# analyzing HL302 6
# read from t=0s to t=2182.82s
# analyzing HL303 6
# read from t=0s to t=2182.82s
# analyzing HL304 6
# read from t=0s to t=2182.82s
# analyzing HL305 6
# read from t=0s to t=2096.58s
# analyzing HL306 6
# read from t=0s to t=2096.58s
# analyzing HL307 6
# read from t=0s to t=2096.58s
# analyzing HL308 6
# read from t=0s to t=2096.58s
# analyzing HL309 6
# read from t=0s to t=2102.45s
# analyzing HL310 6
# read from t=0s to t=2102.45s
# analyzing HL311 6
# read from t=0s to t=2102.45s
# analyzing HL312 6
# read from t=0s to t=2102.45s
# analyzing HL313 6
# read from t=0s to t=1935.69s
# analyzing HL314 6
# read from t=0s to t=1935.69s
# analyzing HL315 6
# read from t=0s to t=1935.69s
# analyzing HL316 6
# read from t=0s to t=1935.69s
# analyzing HL317 6
# read from t=0s to t=1901.21s
# analyzing HL318 6
# read from t=0s to t=1901.21s

# %%
#with open("C://Data//hislight_pickles//HL3_restricted_dark.pickle", 'wb') as handle:
#    pickle.dump(all_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
all_data ={}

for index, row in metafile_data.iterrows():
    if row.phase == "unrestricted_continuous_access_dark":

        key=row.mouse+"_"+str(row.session)
        
        all_data[key]=get_data_from_metafile(row)
# Out:
# analyzing HL301 7
# read from t=0s to t=1940.3s
# analyzing HL302 7
# read from t=0s to t=1940.3s
# analyzing HL303 7
# read from t=0s to t=1940.3s
# analyzing HL304 7
# read from t=0s to t=1940.3s
# analyzing HL305 7
# read from t=0s to t=2002.63s
# analyzing HL306 7
# read from t=0s to t=2002.63s
# analyzing HL307 7
# read from t=0s to t=2002.63s
# analyzing HL308 7
# read from t=0s to t=2002.63s
# analyzing HL309 7
# read from t=0s to t=1962.95s
# analyzing HL310 7
# read from t=0s to t=1962.95s
# analyzing HL311 7
# read from t=0s to t=1962.95s
# analyzing HL312 7
# read from t=0s to t=1962.95s
# analyzing HL313 7
# read from t=0s to t=1950.87s
# analyzing HL314 7
# read from t=0s to t=1950.87s
# analyzing HL315 7
# read from t=0s to t=1950.87s
# analyzing HL316 7
# read from t=0s to t=1950.87s
# analyzing HL317 7
# read from t=0s to t=1883.68s
# analyzing HL318 7
# read from t=0s to t=1883.68s
# analyzing HL301 8
# read from t=0s to t=2111.26s
# analyzing HL302 8
# read from t=0s to t=2111.26s
# analyzing HL303 8
# read from t=0s to t=2111.26s
# analyzing HL304 8
# read from t=0s to t=2111.26s
# analyzing HL305 8
# read from t=0s to t=2185.58s
# analyzing HL306 8
# read from t=0s to t=2185.58s
# analyzing HL307 8
# read from t=0s to t=2185.58s
# analyzing HL308 8
# read from t=0s to t=2185.58s
# analyzing HL309 8
# read from t=0s to t=2109.83s
# analyzing HL310 8
# read from t=0s to t=2109.83s
# analyzing HL311 8
# read from t=0s to t=2109.83s
# analyzing HL312 8
# read from t=0s to t=2109.83s
# analyzing HL313 8
# read from t=0s to t=2024.77s
# analyzing HL314 8
# read from t=0s to t=2024.77s
# analyzing HL315 8
# read from t=0s to t=2024.77s
# analyzing HL316 8
# read from t=0s to t=2024.77s
# analyzing HL317 8
# read from t=0s to t=2094.99s
# analyzing HL318 8
# read from t=0s to t=2094.99s

# %%
#with open("C://Data//hislight_pickles//HL3_adlib_dark.pickle", 'wb') as handle:
#    pickle.dump(all_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
all_data ={}

for index, row in metafile_data.iterrows():
    if row.phase == "unrestricted_sucralose":

        key=row.mouse+"_"+str(row.session)
        
        all_data[key]=get_data_from_metafile(row)
# Out:
# analyzing HL301 9
# read from t=0s to t=2052.96s
# analyzing HL302 9
# read from t=0s to t=2052.96s
# analyzing HL303 9
# read from t=0s to t=2052.96s
# analyzing HL304 9
# read from t=0s to t=2052.96s
# analyzing HL305 9
# read from t=0s to t=2376.59s
# analyzing HL306 9
# read from t=0s to t=2376.59s
# analyzing HL307 9
# read from t=0s to t=2376.59s
# analyzing HL308 9
# read from t=0s to t=2376.59s
# analyzing HL309 9
# read from t=0s to t=2330.46s
# analyzing HL310 9
# read from t=0s to t=2330.46s
# analyzing HL311 9
# read from t=0s to t=2330.46s
# analyzing HL312 9
# read from t=0s to t=2330.46s
# analyzing HL313 9
# read from t=0s to t=2118.64s
# analyzing HL314 9
# read from t=0s to t=2118.64s
# analyzing HL315 9
# read from t=0s to t=2118.64s
# analyzing HL316 9
# read from t=0s to t=2118.64s
# analyzing HL317 9
# read from t=0s to t=2041.3s
# analyzing HL318 9
# read from t=0s to t=2041.3s

# %%
#with open("C://Data//hislight_pickles//HL3_adlib_sucralose.pickle", 'wb') as handle:
#    pickle.dump(all_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
