# %%
import tdt
#import matplotlib.pyplot as plt
#import trompy as tp
import numpy as np
import pickle
import pandas as pd
#%matplotlib inline

# %%
DATAFOLDER = "D:\\Data\\photometry\\HistaLight_cohort2\\"
METAFILE = "..\\data\\HL_cohort2_metafile.csv"

metafile_data = pd.read_csv(METAFILE)

# %%
def get_streams(row, data):

    blue = getattr(data.streams, row.signal_blue).data
    UV = getattr(data.streams,row.signal_uv).data

    fs = getattr(data.streams,row.signal_uv).fs

    corrected = tp.processdata(blue, UV)
    
    return corrected, fs

# %%
def get_ttls(row, data):
 
    if row.R_number_licks> 0:
        return getattr(data.epocs, row.ttl_lick_right).onset
    else:
        return []

# %%
def get_data_from_metafile(row):
    print("analyzing", row.mouse, row.session)
    d= {}

    d["mouse_ID"] = row.mouse
    d["region"] = row.region
    d["virus"] = row.virus
    d["diet"] = row.diet
    d["total_licks"] = row.total_licks
    
    d["solution"]=row.R_nutrient
    
    data = tdt.read_block(DATAFOLDER+row.tdt_file)
    corrected, fs = get_streams(row, data)

    d["corrected"] = corrected
    d["fs"] = fs

    d["licks"] = get_ttls(row, data)
    

    return d
row=metafile_data.iloc[1]
get_data_from_metafile(row)
# Out:
# analyzing HL203 1
# read from t=0s to t=1814.05s
# {'mouse_ID': 'HL203',
#  'region': 'PVH',
#  'virus': 'hislight',
#  'diet': 'chow',
#  'total_licks': 281,
#  'solution': 'ensure',
#  'corrected': array([-16.21146813, -16.21178564, -16.21211004, ..., -11.6774029 ,
#         -11.67557085, -11.67380977]),
#  'fs': 1017.2526245117188,
#  'licks': array([ 256.41140224,  257.78634752,  258.48332288,  258.8483584 ,
#          259.08232192,  259.3292288 ,  259.58334464,  259.72031488,
#          259.84729088,  259.9723008 ,  260.10943488,  260.22526976,
#          260.35634176,  260.48741376,  260.63945728,  260.77544448,
#          260.90143744,  261.0274304 ,  261.16325376,  261.2944896 ,
#          261.43440896,  261.56531712,  261.69524224,  261.82828032,
#          261.9613184 ,  262.10648064,  262.23542272,  262.36731392,
#          262.50723328,  262.63027712,  262.762496  ,  262.9033984 ,
#          263.02939136,  263.16439552,  263.29137152,  263.42227968,
#          263.55449856,  263.67934464,  263.8094336 ,  263.94738688,
#          264.07944192,  264.21641216,  264.34535424,  264.4762624 ,
#          264.60635136,  264.74446848,  264.88127488,  265.00431872,
#          265.14735104,  265.27842304,  265.41146112,  265.54630144,
#          265.68441856,  265.81827584,  265.95524608,  266.09647616,
#          266.2342656 ,  266.36845056,  266.49935872,  266.62944768,
#          266.76740096,  266.89929216,  267.05330176,  267.18339072,
#          267.321344  ,  267.452416  ,  267.59233536,  267.72733952,
#          267.8562816 ,  267.99243264,  268.13530112,  268.26440704,
#          802.56745472, 1461.4953984 , 1463.3713664 , 1464.39421952,
#         1464.65439744, 1465.05416704, 1465.32319232, 1465.61531904,
#         1465.8953216 , 1466.15730176, 1466.4572928 , 1466.71321088,
#         1467.0102528 , 1467.400192  , 1467.6992    , 1468.0932352 ,
#         1468.51528704, 1468.91636736, 1469.33235712, 1469.89449216,
#         1470.31228416, 1471.029248  , 1471.72032512, 1472.40927232,
#         1473.39640832, 1474.21331456, 1475.33037568, 1477.53238528,
#         1478.04831744, 1478.46447104, 1478.86129152, 1479.5743232 ,
#         1480.71235584, 1482.25949696, 1485.10441472, 1486.16036352,
#         1487.90329344])}

# %%
all_data ={}

for index, row in metafile_data.iterrows():
    if row.phase == "unrestricted_continuous_access":

        key=row.mouse+"_"+str(row.session)
        
        all_data[key]=get_data_from_metafile(row)
# Out:
# analyzing HL202 1
# read from t=0s to t=1814.05s
# analyzing HL203 1
# read from t=0s to t=1814.05s
# analyzing HL204 1
# read from t=0s to t=1814.05s
# analyzing HL205 1
# read from t=0s to t=1920.5s
# analyzing HL206 1
# read from t=0s to t=1920.5s
# analyzing HL207 1
# read from t=0s to t=1920.5s
# analyzing HL208 1
# read from t=0s to t=1920.5s
# analyzing HL209 1
# read from t=0s to t=1849.45s
# analyzing HL210 1
# read from t=0s to t=1849.45s
# analyzing HL211 1
# read from t=0s to t=1849.45s
# analyzing HL212 1
# read from t=0s to t=1849.45s
# analyzing HL202 2
# read from t=0s to t=1946.93s
# analyzing HL203 2
# read from t=0s to t=1946.93s
# analyzing HL204 2
# read from t=0s to t=1946.93s
# analyzing HL205 2
# read from t=0s to t=1986.1s
# analyzing HL206 2
# read from t=0s to t=1986.1s
# analyzing HL207 2
# read from t=0s to t=1986.1s
# analyzing HL208 2
# read from t=0s to t=1986.1s
# analyzing HL209 2
# read from t=0s to t=1960.69s
# analyzing HL210 2
# read from t=0s to t=1960.69s
# analyzing HL211 2
# read from t=0s to t=1960.69s
# analyzing HL212 2
# read from t=0s to t=1960.69s
# analyzing HL202 3
# read from t=0s to t=1960.27s
# analyzing HL203 3
# read from t=0s to t=1960.27s
# analyzing HL204 3
# read from t=0s to t=1960.27s
# analyzing HL205 3
# read from t=0s to t=1945.59s
# analyzing HL206 3
# read from t=0s to t=1945.59s
# analyzing HL207 3
# read from t=0s to t=1945.59s
# analyzing HL208 3
# read from t=0s to t=1945.59s
# analyzing HL209 3
# read from t=0s to t=2009.0s
# analyzing HL210 3
# read from t=0s to t=2009.0s
# analyzing HL211 3
# read from t=0s to t=2009.0s
# analyzing HL212 3
# read from t=0s to t=2009.0s

# %%
with open("C://Data//hislight_pickles//adlib_light.pickle", 'wb') as handle:
    pickle.dump(all_data, handle, protocol=pickle.HIGHEST_PROTOCOL)
